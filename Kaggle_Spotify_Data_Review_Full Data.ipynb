# %% [markdown]
# ## MIDS - Spotify Base Data Review

# %%
## to mount GoogleDrive
from google.colab import drive
import os 
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/to_mount')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# base modules
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn.model_selection
import sklearn.metrics

# non-base no import
from pathlib import Path
from bs4 import BeautifulSoup
#from lyricsgenius import Genius
import requests
import seaborn as sns
import json
import xgboost as xgb
import os
import re

# %%
#!pip install spotipy
#!pip install pymusixmatch

# %%
# import packages
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from musixmatch import Musixmatch
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk

# %%
nltk.download(["names","stopwords","state_union","twitter_samples","movie_reviews", "averaged_perceptron_tagger","vader_lexicon","punkt"])
# Out:
# [nltk_data] Downloading package names to /root/nltk_data...
# [nltk_data]   Unzipping corpora/names.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package state_union to /root/nltk_data...
# [nltk_data]   Unzipping corpora/state_union.zip.
# [nltk_data] Downloading package twitter_samples to /root/nltk_data...
# [nltk_data]   Unzipping corpora/twitter_samples.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
#Spotify creds
cid = Path('_keys/cid.txt').read_text()
secret = Path('_keys/secret.txt').read_text()

#Genius creds
# genius_cid = Path('_keys/genius_cid.txt').read_text()
# genius_secret = Path('_keys/genius_secret.txt').read_text()

#Musixmatch creds
musix_cid = Path('_keys/musix_id.txt').read_text()

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# genius = Genius(genius_cid)

# %%
data = pd.read_csv('_data/charts.csv')

# %%
data.head()
# Out:
#                          title  rank        date  \
# 0      Chantaje (feat. Maluma)     1  2017-01-01
# 1  Vente Pa' Ca (feat. Maluma)     2  2017-01-01
# 2   Reggaetón Lento (Bailemos)     3  2017-01-01
# 3                       Safari     4  2017-01-01
# 4                  Shaky Shaky     5  2017-01-01
#
#                                   artist  \
# 0                                Shakira
# 1                           Ricky Martin
# 2                                   CNCO
# 3  J Balvin, Pharrell Williams, BIA, Sky
# 4                           Daddy Yankee
#
#                                                  url     region   chart  \
# 0  https://open.spotify.com/track/6mICuAdrwEjh6Y6...  Argentina  top200
# 1  https://open.spotify.com/track/7DM4BPaS7uofFul...  Argentina  top200
# 2  https://open.spotify.com/track/3AEZUABDXNtecAO...  Argentina  top200
# 3  https://open.spotify.com/track/6rQSrBHf7HlZjtc...  Argentina  top200
# 4  https://open.spotify.com/track/58IL315gMSTD37D...  Argentina  top200
#
#            trend   streams
# 0  SAME_POSITION  253019.0
# 1        MOVE_UP  223988.0
# 2      MOVE_DOWN  210943.0
# 3  SAME_POSITION  173865.0
# 4        MOVE_UP  153956.0

# %%
print(data['chart'].value_counts())
print(data['region'].value_counts())

## suggest narrowing scope to just viral50 in US
# Out:
# top200     20321904
# viral50     5851610
# Name: chart, dtype: int64
# Argentina        455308
# United States    455057
# Austria          454593
# Brazil           454439
# Australia        453103
#                   ...
# Ukraine          127544
# Russia           126837
# Luxembourg        98053
# Andorra           79592
# South Korea       76276
# Name: region, Length: 70, dtype: int64

# %%
use_songs = data.loc[(data.chart == 'viral50') & 
                     (data.region == 'United States')]

# %%
use_songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90873 entries, 53675 to 26173414
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    90873 non-null  object
#  1   rank     90873 non-null  int64
#  2   date     90873 non-null  object
#  3   artist   90873 non-null  object
#  4   url      90873 non-null  object
#  5   region   90873 non-null  object
#  6   chart    90873 non-null  object
#  7   trend    90873 non-null  object
#  8   streams  0 non-null      float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 6.9+ MB

# %%
print("number of unique songs: ", len(use_songs.url.unique()))
print("number of unique artists: ", len(use_songs.artist.unique()))
# Out:
# number of unique songs:  7974
# number of unique artists:  4380

# %%
unique_url = use_songs['url'].unique()

# %%
## get spotify data popularity
def popularity(df):
    empty = []
    for i in df:
      #print(i)
      series_track = pd.Series(sp.track(i))
      empty.append(series_track)
    df2 = pd.DataFrame(empty)
    return df2

spotify_pull = popularity(unique_url)

# %%
spotify_pull
# Out:
#                                                   album  \
# 0     {'album_type': 'single', 'artists': [{'externa...
# 1     {'album_type': 'single', 'artists': [{'externa...
# 2     {'album_type': 'single', 'artists': [{'externa...
# 3     {'album_type': 'single', 'artists': [{'externa...
# 4     {'album_type': 'single', 'artists': [{'externa...
# ...                                                 ...
# 7969  {'album_type': 'single', 'artists': [{'externa...
# 7970  {'album_type': 'single', 'artists': [{'externa...
# 7971  {'album_type': 'album', 'artists': [{'external...
# 7972  {'album_type': 'single', 'artists': [{'externa...
# 7973  {'album_type': 'album', 'artists': [{'external...
#
#                                                 artists  \
# 0     [{'external_urls': {'spotify': 'https://open.s...
# 1     [{'external_urls': {'spotify': 'https://open.s...
# 2     [{'external_urls': {'spotify': 'https://open.s...
# 3     [{'external_urls': {'spotify': 'https://open.s...
# 4     [{'external_urls': {'spotify': 'https://open.s...
# ...                                                 ...
# 7969  [{'external_urls': {'spotify': 'https://open.s...
# 7970  [{'external_urls': {'spotify': 'https://open.s...
# 7971  [{'external_urls': {'spotify': 'https://open.s...
# 7972  [{'external_urls': {'spotify': 'https://open.s...
# 7973  [{'external_urls': {'spotify': 'https://open.s...
#
#                                       available_markets  disc_number  \
# 0     [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 1     [AD, AE, AG, AM, AO, AR, AT, AU, AZ, BB, BD, B...            1
# 2     [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 3                                                    []            1
# 4     [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# ...                                                 ...          ...
# 7969  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 7970  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 7971  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 7972  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 7973  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
#
#       duration_ms  explicit              external_ids  \
# 0          218319     False  {'isrc': 'GBBPW1700118'}
# 1          199741      True  {'isrc': 'TCADD1721892'}
# 2          234285     False  {'isrc': 'USAT21702382'}
# 3          261614      True  {'isrc': 'QZ8TY1700008'}
# 4          162585     False  {'isrc': 'GBAHS1700564'}
# ...           ...       ...                       ...
# 7969       208599     False  {'isrc': 'GBUM72103516'}
# 7970       137341      True  {'isrc': 'USAT22103123'}
# 7971       121572      True  {'isrc': 'USQX92102132'}
# 7972       362293     False  {'isrc': 'USRH10902674'}
# 7973        93176      True  {'isrc': 'USSM12104953'}
#
#                                           external_urls  \
# 0     {'spotify': 'https://open.spotify.com/track/6X...
# 1     {'spotify': 'https://open.spotify.com/track/2A...
# 2     {'spotify': 'https://open.spotify.com/track/57...
# 3     {'spotify': 'https://open.spotify.com/track/0R...
# 4     {'spotify': 'https://open.spotify.com/track/5o...
# ...                                                 ...
# 7969  {'spotify': 'https://open.spotify.com/track/0o...
# 7970  {'spotify': 'https://open.spotify.com/track/7G...
# 7971  {'spotify': 'https://open.spotify.com/track/5B...
# 7972  {'spotify': 'https://open.spotify.com/track/76...
# 7973  {'spotify': 'https://open.spotify.com/track/3m...
#
#                                                    href  \
# 0     https://api.spotify.com/v1/tracks/6XgtAeRYmbr4...
# 1     https://api.spotify.com/v1/tracks/2AEzMPR01sg1...
# 2     https://api.spotify.com/v1/tracks/57p8CBvPOxrv...
# 3     https://api.spotify.com/v1/tracks/0RYXEibxMami...
# 4     https://api.spotify.com/v1/tracks/5o4yGlG0PfeV...
# ...                                                 ...
# 7969  https://api.spotify.com/v1/tracks/0ohcCrxZkBfF...
# 7970  https://api.spotify.com/v1/tracks/7GLqR9ToJLb0...
# 7971  https://api.spotify.com/v1/tracks/5B0kgjHULYJh...
# 7972  https://api.spotify.com/v1/tracks/76oB6OFO1i4U...
# 7973  https://api.spotify.com/v1/tracks/3mXOssdHHkN6...
#
#                           id  is_local  \
# 0     6XgtAeRYmbr4OfEUP3q0D3     False
# 1     2AEzMPR01sg1wsXurYrgDx     False
# 2     57p8CBvPOxrvyCbn6ttl5r     False
# 3     0RYXEibxMami3QuT8kn4Iz     False
# 4     5o4yGlG0PfeVUa6ClIyOxq     False
# ...                      ...       ...
# 7969  0ohcCrxZkBfFbkuRPOZQZX     False
# 7970  7GLqR9ToJLb0PV3XyNAWNm     False
# 7971  5B0kgjHULYJhAQkK5XsMoC     False
# 7972  76oB6OFO1i4UFHL9rUXRlh     False
# 7973  3mXOssdHHkN6AvLw6ZgKiL     False
#
#                                                    name  popularity  \
# 0                                                   LMK          23
# 1                                Turn Up On the Weekend          38
# 2                                        Would You Ever          61
# 3                          Marmalade (feat. Lil Yachty)           0
# 4                                                  Boys          62
# ...                                                 ...         ...
# 7969                             dancing in the kitchen          71
# 7970                          MMM MMM (feat. ATL Jacob)          61
# 7971  WUSYANAME (feat. Youngboy Never Broke Again & ...          78
# 7972                                             Vapors          41
# 7973                                        SAME ENERGY          63
#
#                                             preview_url  track_number   type  \
# 0     https://p.scdn.co/mp3-preview/f45c9bfa1065769d...             1  track
# 1     https://p.scdn.co/mp3-preview/c21e5b0857dfd30e...             1  track
# 2     https://p.scdn.co/mp3-preview/31ee7b84a59f1062...             1  track
# 3                                                  None             1  track
# 4     https://p.scdn.co/mp3-preview/7de075b189146e50...             1  track
# ...                                                 ...           ...    ...
# 7969                                               None             1  track
# 7970  https://p.scdn.co/mp3-preview/85a83a7e0331da36...             1  track
# 7971  https://p.scdn.co/mp3-preview/990a314a1de86e2e...             4  track
# 7972  https://p.scdn.co/mp3-preview/da2b1ada844e6695...             2  track
# 7973  https://p.scdn.co/mp3-preview/336a10ae9bb31364...             4  track
#
#                                        uri
# 0     spotify:track:6XgtAeRYmbr4OfEUP3q0D3
# 1     spotify:track:2AEzMPR01sg1wsXurYrgDx
# 2     spotify:track:57p8CBvPOxrvyCbn6ttl5r
# 3     spotify:track:0RYXEibxMami3QuT8kn4Iz
# 4     spotify:track:5o4yGlG0PfeVUa6ClIyOxq
# ...                                    ...
# 7969  spotify:track:0ohcCrxZkBfFbkuRPOZQZX
# 7970  spotify:track:7GLqR9ToJLb0PV3XyNAWNm
# 7971  spotify:track:5B0kgjHULYJhAQkK5XsMoC
# 7972  spotify:track:76oB6OFO1i4UFHL9rUXRlh
# 7973  spotify:track:3mXOssdHHkN6AvLw6ZgKiL
#
# [7974 rows x 17 columns]

# %%
spotify_pull.to_csv('viral50_use.csv')

# %%
spotify_pull = pd.read_csv('viral50_use.csv')

# %% [markdown]
# Plot distribution of popularity score.

# %%
sns.histplot(data = spotify_pull
            ,x = 'popularity'
            ).set(title='Total Popularity Distribution')
# Out:
# [Text(0.5, 1.0, 'Total Popularity Distribution')]

# %%
sns.histplot(data = spotify_pull.loc[spotify_pull['popularity'] > 0]
            ,x = 'popularity'
            ).set(title='Non-0 Popularity Distribution')
# Out:
# [Text(0.5, 1.0, 'Non-0 Popularity Distribution')]

# %%
## remove any songs with no popularity - assuming these are too small to be considered
electro_short = spotify_pull.loc[spotify_pull['popularity'] > 0]

# %%
# parse artist names from JSON response
def parse_artist(df):
  empty = []
  for i in df['artists']:
    line_artists = []
    try:
      artist_lists = json.loads(i.replace("\'", "\""))
    except:
      #print(i)
      artists_lists = []
    for j in artist_lists:
      line_artists.append(j['name'])
    empty.append(line_artists)
  return empty


electro_short['artist_names'] = parse_artist(electro_short)
electro_short['first_artist'] = electro_short.apply(lambda row: row.artist_names[0], axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
out = pd.DataFrame(electro_short.first_artist.value_counts())
out
# Out:
#             first_artist
# Drake                 31
# Prince                29
# Ed Sheeran            28
# DMX                   28
# Khalid                22
# ...                  ...
# Katy Perry             1
# Videoclub              1
# PopLord                1
# Sam Feldt              1
# Fase Yoda              1
#
# [2704 rows x 1 columns]

# %%
sns.histplot(data = out.loc[out['first_artist'] < 40]
            ,x = 'first_artist'
            ).set(title='Arist Song Count')
# Out:
# [Text(0.5, 1.0, 'Arist Song Count')]

# %%
electro_short
# Out:
#       Unnamed: 0                                              album  \
# 0              0  {'album_type': 'single', 'artists': [{'externa...
# 1              1  {'album_type': 'single', 'artists': [{'externa...
# 2              2  {'album_type': 'single', 'artists': [{'externa...
# 4              4  {'album_type': 'single', 'artists': [{'externa...
# 5              5  {'album_type': 'single', 'artists': [{'externa...
# ...          ...                                                ...
# 7969        7969  {'album_type': 'single', 'artists': [{'externa...
# 7970        7970  {'album_type': 'single', 'artists': [{'externa...
# 7971        7971  {'album_type': 'album', 'artists': [{'external...
# 7972        7972  {'album_type': 'single', 'artists': [{'externa...
# 7973        7973  {'album_type': 'album', 'artists': [{'external...
#
#                                                 artists  \
# 0     [{'external_urls': {'spotify': 'https://open.s...
# 1     [{'external_urls': {'spotify': 'https://open.s...
# 2     [{'external_urls': {'spotify': 'https://open.s...
# 4     [{'external_urls': {'spotify': 'https://open.s...
# 5     [{'external_urls': {'spotify': 'https://open.s...
# ...                                                 ...
# 7969  [{'external_urls': {'spotify': 'https://open.s...
# 7970  [{'external_urls': {'spotify': 'https://open.s...
# 7971  [{'external_urls': {'spotify': 'https://open.s...
# 7972  [{'external_urls': {'spotify': 'https://open.s...
# 7973  [{'external_urls': {'spotify': 'https://open.s...
#
#                                       available_markets  disc_number  \
# 0     ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...            1
# 1     ['AD', 'AE', 'AG', 'AM', 'AO', 'AR', 'AT', 'AU...            1
# 2     ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...            1
# 4     ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...            1
# 5     ['AD', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU...            1
# ...                                                 ...          ...
# 7969  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...            1
# 7970  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...            1
# 7971  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...            1
# 7972  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...            1
# 7973  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...            1
#
#       duration_ms  explicit              external_ids  \
# 0          218319     False  {'isrc': 'GBBPW1700118'}
# 1          199741      True  {'isrc': 'TCADD1721892'}
# 2          234285     False  {'isrc': 'USAT21702382'}
# 4          162585     False  {'isrc': 'GBAHS1700564'}
# 5          190427      True  {'isrc': 'GBHMU1700037'}
# ...           ...       ...                       ...
# 7969       208599     False  {'isrc': 'GBUM72103516'}
# 7970       137341      True  {'isrc': 'USAT22103123'}
# 7971       121572      True  {'isrc': 'USQX92102132'}
# 7972       362293     False  {'isrc': 'USRH10902674'}
# 7973        93176      True  {'isrc': 'USSM12104953'}
#
#                                           external_urls  \
# 0     {'spotify': 'https://open.spotify.com/track/6X...
# 1     {'spotify': 'https://open.spotify.com/track/2A...
# 2     {'spotify': 'https://open.spotify.com/track/57...
# 4     {'spotify': 'https://open.spotify.com/track/5o...
# 5     {'spotify': 'https://open.spotify.com/track/7F...
# ...                                                 ...
# 7969  {'spotify': 'https://open.spotify.com/track/0o...
# 7970  {'spotify': 'https://open.spotify.com/track/7G...
# 7971  {'spotify': 'https://open.spotify.com/track/5B...
# 7972  {'spotify': 'https://open.spotify.com/track/76...
# 7973  {'spotify': 'https://open.spotify.com/track/3m...
#
#                                                    href  \
# 0     https://api.spotify.com/v1/tracks/6XgtAeRYmbr4...
# 1     https://api.spotify.com/v1/tracks/2AEzMPR01sg1...
# 2     https://api.spotify.com/v1/tracks/57p8CBvPOxrv...
# 4     https://api.spotify.com/v1/tracks/5o4yGlG0PfeV...
# 5     https://api.spotify.com/v1/tracks/7F9vK8hNFMml...
# ...                                                 ...
# 7969  https://api.spotify.com/v1/tracks/0ohcCrxZkBfF...
# 7970  https://api.spotify.com/v1/tracks/7GLqR9ToJLb0...
# 7971  https://api.spotify.com/v1/tracks/5B0kgjHULYJh...
# 7972  https://api.spotify.com/v1/tracks/76oB6OFO1i4U...
# 7973  https://api.spotify.com/v1/tracks/3mXOssdHHkN6...
#
#                           id  is_local  \
# 0     6XgtAeRYmbr4OfEUP3q0D3     False
# 1     2AEzMPR01sg1wsXurYrgDx     False
# 2     57p8CBvPOxrvyCbn6ttl5r     False
# 4     5o4yGlG0PfeVUa6ClIyOxq     False
# 5     7F9vK8hNFMml4GtHsaXui6     False
# ...                      ...       ...
# 7969  0ohcCrxZkBfFbkuRPOZQZX     False
# 7970  7GLqR9ToJLb0PV3XyNAWNm     False
# 7971  5B0kgjHULYJhAQkK5XsMoC     False
# 7972  76oB6OFO1i4UFHL9rUXRlh     False
# 7973  3mXOssdHHkN6AvLw6ZgKiL     False
#
#                                                    name  popularity  \
# 0                                                   LMK          23
# 1                                Turn Up On the Weekend          38
# 2                                        Would You Ever          61
# 4                                                  Boys          62
# 5     Back to You (feat. Bebe Rexha & Digital Farm A...          69
# ...                                                 ...         ...
# 7969                             dancing in the kitchen          71
# 7970                          MMM MMM (feat. ATL Jacob)          61
# 7971  WUSYANAME (feat. Youngboy Never Broke Again & ...          78
# 7972                                             Vapors          41
# 7973                                        SAME ENERGY          63
#
#                                             preview_url  track_number   type  \
# 0     https://p.scdn.co/mp3-preview/f45c9bfa1065769d...             1  track
# 1     https://p.scdn.co/mp3-preview/c21e5b0857dfd30e...             1  track
# 2     https://p.scdn.co/mp3-preview/31ee7b84a59f1062...             1  track
# 4     https://p.scdn.co/mp3-preview/7de075b189146e50...             1  track
# 5     https://p.scdn.co/mp3-preview/de5c20b97f938aa7...             1  track
# ...                                                 ...           ...    ...
# 7969                                                NaN             1  track
# 7970  https://p.scdn.co/mp3-preview/85a83a7e0331da36...             1  track
# 7971  https://p.scdn.co/mp3-preview/990a314a1de86e2e...             4  track
# 7972  https://p.scdn.co/mp3-preview/da2b1ada844e6695...             2  track
# 7973  https://p.scdn.co/mp3-preview/336a10ae9bb31364...             4  track
#
#                                        uri  \
# 0     spotify:track:6XgtAeRYmbr4OfEUP3q0D3
# 1     spotify:track:2AEzMPR01sg1wsXurYrgDx
# 2     spotify:track:57p8CBvPOxrvyCbn6ttl5r
# 4     spotify:track:5o4yGlG0PfeVUa6ClIyOxq
# 5     spotify:track:7F9vK8hNFMml4GtHsaXui6
# ...                                    ...
# 7969  spotify:track:0ohcCrxZkBfFbkuRPOZQZX
# 7970  spotify:track:7GLqR9ToJLb0PV3XyNAWNm
# 7971  spotify:track:5B0kgjHULYJhAQkK5XsMoC
# 7972  spotify:track:76oB6OFO1i4UFHL9rUXRlh
# 7973  spotify:track:3mXOssdHHkN6AvLw6ZgKiL
#
#                                            artist_names        first_artist
# 0                                              [Kelela]              Kelela
# 1                                   [Branchez, Big Wet]            Branchez
# 2                                  [Skrillex, Poo Bear]            Skrillex
# 4                                          [Charli XCX]          Charli XCX
# 5     [Louis Tomlinson, Bebe Rexha, Digital Farm Ani...     Louis Tomlinson
# ...                                                 ...                 ...
# 7969                                             [LANY]                LANY
# 7970                                  [Kali, ATL Jacob]                Kali
# 7971  [Tyler, The Creator, YoungBoy Never Broke Agai...  Tyler, The Creator
# 7972                                       [Biz Markie]          Biz Markie
# 7973                                    [The Kid LAROI]       The Kid LAROI
#
# [5587 rows x 20 columns]

# %%
use_cols = ['href', 'popularity', 'name', 'first_artist']
electro_short_join = electro_short[use_cols]

# %%
electro_short_join
# Out:
#                                                    href  popularity  \
# 0     https://api.spotify.com/v1/tracks/6XgtAeRYmbr4...          23
# 1     https://api.spotify.com/v1/tracks/2AEzMPR01sg1...          38
# 2     https://api.spotify.com/v1/tracks/57p8CBvPOxrv...          61
# 4     https://api.spotify.com/v1/tracks/5o4yGlG0PfeV...          62
# 5     https://api.spotify.com/v1/tracks/7F9vK8hNFMml...          69
# ...                                                 ...         ...
# 7969  https://api.spotify.com/v1/tracks/0ohcCrxZkBfF...          71
# 7970  https://api.spotify.com/v1/tracks/7GLqR9ToJLb0...          61
# 7971  https://api.spotify.com/v1/tracks/5B0kgjHULYJh...          78
# 7972  https://api.spotify.com/v1/tracks/76oB6OFO1i4U...          41
# 7973  https://api.spotify.com/v1/tracks/3mXOssdHHkN6...          63
#
#                                                    name        first_artist
# 0                                                   LMK              Kelela
# 1                                Turn Up On the Weekend            Branchez
# 2                                        Would You Ever            Skrillex
# 4                                                  Boys          Charli XCX
# 5     Back to You (feat. Bebe Rexha & Digital Farm A...     Louis Tomlinson
# ...                                                 ...                 ...
# 7969                             dancing in the kitchen                LANY
# 7970                          MMM MMM (feat. ATL Jacob)                Kali
# 7971  WUSYANAME (feat. Youngboy Never Broke Again & ...  Tyler, The Creator
# 7972                                             Vapors          Biz Markie
# 7973                                        SAME ENERGY       The Kid LAROI
#
# [5587 rows x 4 columns]

# %%
## Create dictionary to track model results
results = {}

def add_results(y_pred, model_name):
    ## Add results of test data to tracker, with user input to ensure data is overwritten on purpose
    if model_name in results.keys():
        userIn = input("Model already in dictionary. Add? ").lower()
        if userIn == 'yes':
            results[model_name] = round(sklearn.metrics.mean_squared_error(y_test, y_pred), 2)**.5
        else:
            pass
    else:
        results[model_name] = round(sklearn.metrics.mean_squared_error(y_test, y_pred), 2)**.5
    print(results)

# %% [markdown]
# ## pull from MusixMatch

# %%
electro_short_join.head()
# Out:
#                                                 href  popularity  \
# 0  https://api.spotify.com/v1/tracks/6XgtAeRYmbr4...          23
# 1  https://api.spotify.com/v1/tracks/2AEzMPR01sg1...          38
# 2  https://api.spotify.com/v1/tracks/57p8CBvPOxrv...          61
# 4  https://api.spotify.com/v1/tracks/5o4yGlG0PfeV...          62
# 5  https://api.spotify.com/v1/tracks/7F9vK8hNFMml...          69
#
#                                                 name     first_artist
# 0                                                LMK           Kelela
# 1                             Turn Up On the Weekend         Branchez
# 2                                     Would You Ever         Skrillex
# 4                                               Boys       Charli XCX
# 5  Back to You (feat. Bebe Rexha & Digital Farm A...  Louis Tomlinson

# %%
musixmatch = Musixmatch(musix_cid)

def parse_lyrics(df):
  empty = []
  for row, artist in df.first_artist.iteritems():
    song_title = df['name'].loc[row]
    lyrics_return = ''
    #print(song_title)
    #print(artist)
    try:
      track_return = musixmatch.matcher_track_get(song_title, artist)
      if track_return['message']['body']['track']['has_lyrics'] == 1:
        lyrics_return = musixmatch.track_lyrics_get(track_return['message']['body']['track']['track_id'])['message']['body']['lyrics']['lyrics_body']
    except:
      lyrics_return = ''
    empty.append(lyrics_return)
  return empty

full_lyrics = parse_lyrics(electro_short_join)

# %%
electro_short_join['lyrics'] = full_lyrics
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
## clean lyrics
electro_short_join['lyrics_clean'] = electro_short_join['lyrics'].str.replace('******* This Lyrics is NOT for Commercial use *******\n(1409622602394)', '',regex=False).str.replace('\n', ' ', regex=False)
electro_short_join['char_len'] = electro_short_join['lyrics_clean'].str.len()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
electro_short_join.to_csv('viral_w_lyrics.csv')

# %%
electro_short_join = pd.read_csv('viral_w_lyrics.csv')

# %%
# prep sentiment analysis
sia = SentimentIntensityAnalyzer()

# %%
def get_sentiment(df):
  empty = []

  for lyrics in df.lyrics_clean:

    if pd.isna(lyrics):
      lyrics = ''

    #print(lyrics)
    output = sia.polarity_scores(lyrics)
    empty.append(output)
    
  return empty

sentiment_scores = pd.DataFrame(get_sentiment(electro_short_join))
final_sentiment = pd.concat([electro_short_join.reset_index(), sentiment_scores.reset_index()], axis=1)

# %%
## bring in GloVe
from gensim.scripts.glove2word2vec import glove2word2vec
from gensim.models import KeyedVectors

glove_filename = 'glove.6B.50d.txt'

word2vec_output_file = glove_filename+'.word2vec'
glove2word2vec('glove.6B.50d.txt', word2vec_output_file)

# load the Stanford GloVe model
word2vec_output_file = glove_filename+'.word2vec'
model = KeyedVectors.load_word2vec_format(word2vec_output_file, binary=False)

# %%
v = model.get_vector('king')
D = v.shape[0]

X = np.zeros((len(final_sentiment.lyrics_clean), D))
n = 0
emptycount = 0

for sentence in final_sentiment.lyrics_clean:
  
  if pd.isna(sentence):
    sentence = ''
  
  tokens = sentence.split()
  vecs = []
  m = 0
  
  for word in tokens:
    
    try:
      # throws KeyError if word not found
      vec = model.get_vector(word)
      vecs = np.append(vecs, vec)
      m += 1
    except KeyError:
      pass
    
  if len(vecs) > 0:
    vecs = np.array(vecs)
    X[n] = vecs.mean(axis=0)
  else:
    emptycount += 1  
  n += 1

print(emptycount)
print(n)
# Out:
# 705
# 5587

# %%
df_GloVe = pd.DataFrame(X)
df_GloVe.columns = ['GloVe' + str(x) for x in range(50)]

final_sentiment2 = pd.concat([final_sentiment.reset_index(), df_GloVe.reset_index()], axis=1)

# %%
agg_cols = {'neg':'mean',
            'neu':'mean',
            'pos':'mean',
            'compound':'mean',
            'GloVe0': 'mean',
            'GloVe1': 'mean',
            'GloVe2': 'mean',
            'GloVe3': 'mean',
            'GloVe4': 'mean',
            'GloVe5': 'mean',
            'GloVe6': 'mean',
            'GloVe7': 'mean',
            'GloVe8': 'mean',
            'GloVe9': 'mean',
            'GloVe10': 'mean',
            'GloVe11': 'mean',
            'GloVe12': 'mean',
            'GloVe13': 'mean',
            'GloVe14': 'mean',
            'GloVe15': 'mean',
            'GloVe16': 'mean',
            'GloVe17': 'mean',
            'GloVe18': 'mean',
            'GloVe19': 'mean',
            'GloVe20': 'mean',
            'GloVe21': 'mean',
            'GloVe22': 'mean',
            'GloVe23': 'mean',
            'GloVe24': 'mean',
            'GloVe25': 'mean',
            'GloVe26': 'mean',
            'GloVe27': 'mean',
            'GloVe28': 'mean',
            'GloVe29': 'mean',
            'GloVe30': 'mean',
            'GloVe31': 'mean',
            'GloVe32': 'mean',
            'GloVe33': 'mean',
            'GloVe34': 'mean',
            'GloVe35': 'mean',
            'GloVe36': 'mean',
            'GloVe37': 'mean',
            'GloVe38': 'mean',
            'GloVe39': 'mean',
            'GloVe40': 'mean',
            'GloVe41': 'mean',
            'GloVe42': 'mean',
            'GloVe43': 'mean',
            'GloVe44': 'mean',
            'GloVe45': 'mean',
            'GloVe46': 'mean',
            'GloVe47': 'mean',
            'GloVe48': 'mean',
            'GloVe49': 'mean',
            'popularity': 'mean'}

electro_agg_metrics = final_sentiment2.groupby('first_artist').agg(agg_cols)

electro_agg_metrics
# Out:
#                                 neg       neu     pos  compound    GloVe0  \
# first_artist
# $NOT                       0.076000  0.810000  0.1150  0.594000  0.029750
# $ilkMoney                  0.161000  0.797000  0.0410 -0.937300  0.038465
# $uicideboy$                0.158000  0.717200  0.1248  0.010340  0.028319
# (G)I-DLE                   0.000000  0.779000  0.2210  0.973700  0.056550
# 070 Shake                  0.119333  0.769333  0.1120 -0.079967  0.042568
# ...                             ...       ...     ...       ...       ...
# ⣎⡇ꉺლ༽இ•̛)ྀ◞ ༎ຶ ༽ৣৢ؞ৢ؞ؖ ꉺლ  0.000000  0.000000  0.0000  0.000000  0.000000
# ギヴン                        0.000000  1.000000  0.0000  0.000000  0.063689
# 吴亦凡                        0.117000  0.758000  0.1240  0.145100  0.057992
# 稲葉曇                        0.000000  0.000000  0.0000  0.000000  0.000000
# 遠野高志                       0.000000  0.000000  0.0000  0.000000  0.000000
#
#                              GloVe1    GloVe2    GloVe3    GloVe4    GloVe5  \
# first_artist
# $NOT                       0.029750  0.029750  0.029750  0.029750  0.029750
# $ilkMoney                  0.038465  0.038465  0.038465  0.038465  0.038465
# $uicideboy$                0.028319  0.028319  0.028319  0.028319  0.028319
# (G)I-DLE                   0.056550  0.056550  0.056550  0.056550  0.056550
# 070 Shake                  0.042568  0.042568  0.042568  0.042568  0.042568
# ...                             ...       ...       ...       ...       ...
# ⣎⡇ꉺლ༽இ•̛)ྀ◞ ༎ຶ ༽ৣৢ؞ৢ؞ؖ ꉺლ  0.000000  0.000000  0.000000  0.000000  0.000000
# ギヴン                        0.063689  0.063689  0.063689  0.063689  0.063689
# 吴亦凡                        0.057992  0.057992  0.057992  0.057992  0.057992
# 稲葉曇                        0.000000  0.000000  0.000000  0.000000  0.000000
# 遠野高志                       0.000000  0.000000  0.000000  0.000000  0.000000
#
#                            ...   GloVe41   GloVe42   GloVe43   GloVe44  \
# first_artist               ...
# $NOT                       ...  0.029750  0.029750  0.029750  0.029750
# $ilkMoney                  ...  0.038465  0.038465  0.038465  0.038465
# $uicideboy$                ...  0.028319  0.028319  0.028319  0.028319
# (G)I-DLE                   ...  0.056550  0.056550  0.056550  0.056550
# 070 Shake                  ...  0.042568  0.042568  0.042568  0.042568
# ...                        ...       ...       ...       ...       ...
# ⣎⡇ꉺლ༽இ•̛)ྀ◞ ༎ຶ ༽ৣৢ؞ৢ؞ؖ ꉺლ  ...  0.000000  0.000000  0.000000  0.000000
# ギヴン                        ...  0.063689  0.063689  0.063689  0.063689
# 吴亦凡                        ...  0.057992  0.057992  0.057992  0.057992
# 稲葉曇                        ...  0.000000  0.000000  0.000000  0.000000
# 遠野高志                       ...  0.000000  0.000000  0.000000  0.000000
#
#                             GloVe45   GloVe46   GloVe47   GloVe48   GloVe49  \
# first_artist
# $NOT                       0.029750  0.029750  0.029750  0.029750  0.029750
# $ilkMoney                  0.038465  0.038465  0.038465  0.038465  0.038465
# $uicideboy$                0.028319  0.028319  0.028319  0.028319  0.028319
# (G)I-DLE                   0.056550  0.056550  0.056550  0.056550  0.056550
# 070 Shake                  0.042568  0.042568  0.042568  0.042568  0.042568
# ...                             ...       ...       ...       ...       ...
# ⣎⡇ꉺლ༽இ•̛)ྀ◞ ༎ຶ ༽ৣৢ؞ৢ؞ؖ ꉺლ  0.000000  0.000000  0.000000  0.000000  0.000000
# ギヴン                        0.063689  0.063689  0.063689  0.063689  0.063689
# 吴亦凡                        0.057992  0.057992  0.057992  0.057992  0.057992
# 稲葉曇                        0.000000  0.000000  0.000000  0.000000  0.000000
# 遠野高志                       0.000000  0.000000  0.000000  0.000000  0.000000
#
#                            popularity
# first_artist
# $NOT                        52.000000
# $ilkMoney                   69.000000
# $uicideboy$                 56.400000
# (G)I-DLE                    65.000000
# 070 Shake                   54.666667
# ...                               ...
# ⣎⡇ꉺლ༽இ•̛)ྀ◞ ༎ຶ ༽ৣৢ؞ৢ؞ؖ ꉺლ   41.000000
# ギヴン                         67.000000
# 吴亦凡                         33.000000
# 稲葉曇                         69.000000
# 遠野高志                        65.000000
#
# [2704 rows x 55 columns]

# %%
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(electro_agg_metrics.drop('popularity', axis = 1), 
                                                                            electro_agg_metrics.popularity,
                                                    random_state = 1111,
                                                    test_size = 0.3)

# %%
XGB_MVP = xgb.XGBRegressor(objective='reg:squarederror',
                                seed=100).fit(X_train, y_train)
add_results(XGB_MVP.predict(X_test), "XGB_Base_lyrics")
# Out:
# {'XGB_Base_lyrics': 18.815684946341975}

# %%
## Run GridSearchCV on max_depth, min_child_weight, n_estimators, and subsample

param_test = {
 'max_depth':range(2,5,1),
 'min_child_weight':range(3,10,2),
 'subsample':[i/100.0 for i in range(70,90,5)],
 'n_estimator':range(150,300,50)
}

gsearch1 = sklearn.model_selection.GridSearchCV(estimator=xgb.XGBRegressor(objective='reg:squarederror', eta=0.025,
                                                                           seed=100),param_grid=param_test, 
                                                                           cv=4)
gsearch1.fit(X_train, y_train)
gsearch1.best_estimator_
# Out:
# XGBRegressor(eta=0.025, max_depth=2, min_child_weight=7, n_estimator=150,
#              objective='reg:squarederror', seed=100, subsample=0.8)

# %%
## Select final number of estimators
params = {'eta':0.025, 'seed':100, 
         'max_depth':2, 'min_child_weight':7, 'subsample':0.8, 'objective':'reg:squarederror'}

## Run CV to determine the number of round
CVRun = xgb.cv(
            params=params,
            dtrain=xgb.DMatrix(X_train, label=y_train),
            num_boost_round=500,
            nfold=4,
            metrics='rmse',
            seed=100)

CVRun.drop(['train-rmse-std', 'test-rmse-std'], axis=1, inplace=True)
CVRun.plot(figsize = (10,5), grid = True)

# %%
## Selected 300 as the number of rounds to avoid over fitting

XGB_hyperparam = xgb.train(params, xgb.DMatrix(X_train, label=y_train), 140)
add_results(XGB_hyperparam.predict(xgb.DMatrix(X_test)), "XGB_Hyperparam_lyrics")
# Out:
# {'XGB_Base_lyrics': 18.815684946341975, 'XGB_Hyperparam_lyrics': 18.732591918898997}

# %%
plt.figure(figsize=(10,10))
plt.scatter(y_test, XGB_hyperparam.predict(xgb.DMatrix(X_test)), c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(XGB_hyperparam.predict(xgb.DMatrix(X_test))), max(y_test))
p2 = min(min(XGB_hyperparam.predict(xgb.DMatrix(X_test))), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()

# %%
non_zero = electro_agg_metrics.loc[electro_agg_metrics.GloVe46 != 0]

X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(non_zero.drop('popularity', axis = 1), 
                                                                            non_zero.popularity,
                                                    random_state = 1111,
                                                    test_size = 0.3)

# %%
XGB_MVP = xgb.XGBRegressor(objective='reg:squarederror',
                                seed=100).fit(X_train, y_train)
add_results(XGB_MVP.predict(X_test), "XGB_Base_lyrics_nonZero")
# Out:
# {'XGB_Base_lyrics': 18.815684946341975, 'XGB_Hyperparam_lyrics': 18.732591918898997, 'XGB_Base_lyrics_nonZero': 18.934360300786505}

# %%
## Selected 300 as the number of rounds to avoid over fitting

XGB_hyperparam = xgb.train(params, xgb.DMatrix(X_train, label=y_train), 140)
add_results(XGB_hyperparam.predict(xgb.DMatrix(X_test)), "XGB_Hyperparam_lyrics_nonZero")
# Out:
# {'XGB_Base_lyrics': 18.815684946341975, 'XGB_Hyperparam_lyrics': 18.732591918898997, 'XGB_Base_lyrics_nonZero': 18.934360300786505, 'XGB_Hyperparam_lyrics_nonZero': 18.585478202080246}

# %%
plt.figure(figsize=(10,10))
plt.scatter(y_test, XGB_hyperparam.predict(xgb.DMatrix(X_test)), c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(XGB_hyperparam.predict(xgb.DMatrix(X_test))), max(y_test))
p2 = min(min(XGB_hyperparam.predict(xgb.DMatrix(X_test))), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()
