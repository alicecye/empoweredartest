# %% [markdown]
# ## MIDS - Spotify Base Data Review

# %%
# base modules
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn.model_selection
import sklearn.metrics

# non-base no import
from pathlib import Path
from bs4 import BeautifulSoup
#from lyricsgenius import Genius
import requests
import seaborn as sns
import json
import xgboost as xgb
import os
import re

# %%
#!pip install spotipy
#!pip install pymusixmatch

# %%
# import packages
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from musixmatch import Musixmatch
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk

# %%
nltk.download(["names","stopwords","state_union","twitter_samples","movie_reviews", "averaged_perceptron_tagger","vader_lexicon","punkt"])
# Out:
# [nltk_data] Downloading package names to /root/nltk_data...
# [nltk_data]   Unzipping corpora/names.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package state_union to /root/nltk_data...
# [nltk_data]   Unzipping corpora/state_union.zip.
# [nltk_data] Downloading package twitter_samples to /root/nltk_data...
# [nltk_data]   Unzipping corpora/twitter_samples.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
#Spotify creds
cid = Path('_keys/cid.txt').read_text()
secret = Path('_keys/secret.txt').read_text()

#Genius creds
# genius_cid = Path('_keys/genius_cid.txt').read_text()
# genius_secret = Path('_keys/genius_secret.txt').read_text()

#Musixmatch creds
musix_cid = Path('_keys/musix_id.txt').read_text()

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# genius = Genius(genius_cid)

# %%
genres = pd.read_csv('_data/genres_v2.csv')
playlist = pd.read_csv('_data/playlists.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
genres['genre'].value_counts()
# Out:
# Underground Rap    5875
# Dark Trap          4578
# Hiphop             3028
# trance             2999
# trap               2987
# techhouse          2975
# dnb                2966
# psytrance          2961
# techno             2956
# hardstyle          2936
# RnB                2099
# Trap Metal         1956
# Rap                1848
# Emo                1680
# Pop                 461
# Name: genre, dtype: int64

# %%
## subset to just electro-related count
use_genres = ['Underground Rap', 'Hiphop', 'Rap']

use_songs = genres[genres.genre.isin(use_genres)]

# %%
unique_uri = use_songs['uri'].unique()

# %%
## get song popularity
def popularity(df):
    empty = []
    for i in df:
      print(i)
      series_track = pd.Series(sp.track(i))
      empty.append(series_track)
    df2 = pd.DataFrame(empty)
    return df2

electro_popularity = popularity(unique_uri)

# %%
electro_popularity
# Out:
#                                                   album  \
# 0     {'album_type': 'single', 'artists': [{'externa...
# 1     {'album_type': 'single', 'artists': [{'externa...
# 2     {'album_type': 'album', 'artists': [{'external...
# 3     {'album_type': 'single', 'artists': [{'externa...
# 4     {'album_type': 'single', 'artists': [{'externa...
# ...                                                 ...
# 9677  {'album_type': 'album', 'artists': [{'external...
# 9678  {'album_type': 'album', 'artists': [{'external...
# 9679  {'album_type': 'album', 'artists': [{'external...
# 9680  {'album_type': 'album', 'artists': [{'external...
# 9681  {'album_type': 'album', 'artists': [{'external...
#
#                                                 artists  \
# 0     [{'external_urls': {'spotify': 'https://open.s...
# 1     [{'external_urls': {'spotify': 'https://open.s...
# 2     [{'external_urls': {'spotify': 'https://open.s...
# 3     [{'external_urls': {'spotify': 'https://open.s...
# 4     [{'external_urls': {'spotify': 'https://open.s...
# ...                                                 ...
# 9677  [{'external_urls': {'spotify': 'https://open.s...
# 9678  [{'external_urls': {'spotify': 'https://open.s...
# 9679  [{'external_urls': {'spotify': 'https://open.s...
# 9680  [{'external_urls': {'spotify': 'https://open.s...
# 9681  [{'external_urls': {'spotify': 'https://open.s...
#
#                                       available_markets  disc_number  \
# 0     [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 1     [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 2                                                    []            1
# 3     [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 4                                                    []            1
# ...                                                 ...          ...
# 9677  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 9678  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 9679  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 9680  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 9681                                                 []            1
#
#       duration_ms  explicit              external_ids  \
# 0          221596      True  {'isrc': 'QZMEN2016068'}
# 1          169254      True  {'isrc': 'QZHNC2012043'}
# 2          152772      True  {'isrc': 'QZMHP2080017'}
# 3          158824      True  {'isrc': 'QZNWQ2097021'}
# 4          145681      True  {'isrc': 'QZNMU2069069'}
# ...           ...       ...                       ...
# 9677       281885      True  {'isrc': 'US6R21496285'}
# 9678       209581      True  {'isrc': 'QM6MZ2095135'}
# 9679       213898      True  {'isrc': 'QM6MZ2095142'}
# 9680       271866      True  {'isrc': 'US6R21482692'}
# 9681       182040      True  {'isrc': 'US2S70508004'}
#
#                                           external_urls  \
# 0     {'spotify': 'https://open.spotify.com/track/2M...
# 1     {'spotify': 'https://open.spotify.com/track/0G...
# 2     {'spotify': 'https://open.spotify.com/track/7i...
# 3     {'spotify': 'https://open.spotify.com/track/7p...
# 4     {'spotify': 'https://open.spotify.com/track/1x...
# ...                                                 ...
# 9677  {'spotify': 'https://open.spotify.com/track/54...
# 9678  {'spotify': 'https://open.spotify.com/track/4Y...
# 9679  {'spotify': 'https://open.spotify.com/track/03...
# 9680  {'spotify': 'https://open.spotify.com/track/7o...
# 9681  {'spotify': 'https://open.spotify.com/track/2k...
#
#                                                    href  \
# 0     https://api.spotify.com/v1/tracks/2MKznt3SBUur...
# 1     https://api.spotify.com/v1/tracks/0GpHpTBnQ1VZ...
# 2     https://api.spotify.com/v1/tracks/7in64eGZcfSb...
# 3     https://api.spotify.com/v1/tracks/7pR6pkqITDQS...
# 4     https://api.spotify.com/v1/tracks/1xWbHRmEAvMX...
# ...                                                 ...
# 9677  https://api.spotify.com/v1/tracks/54v6Kv41W8AK...
# 9678  https://api.spotify.com/v1/tracks/4YuGxSdxyL6f...
# 9679  https://api.spotify.com/v1/tracks/034dSXepspHa...
# 9680  https://api.spotify.com/v1/tracks/7oCZpPJcPDZf...
# 9681  https://api.spotify.com/v1/tracks/2kpwzDrLK5Ko...
#
#                           id  is_local  \
# 0     2MKznt3SBUurI2dhGBhgKG     False
# 1     0GpHpTBnQ1VZdlfyBGeoKr     False
# 2     7in64eGZcfSb6Ag9modv0f     False
# 3     7pR6pkqITDQSGhSJOzRjWh     False
# 4     1xWbHRmEAvMXT9nnUtRJM8     False
# ...                      ...       ...
# 9677  54v6Kv41W8AKToCb14PmJD     False
# 9678  4YuGxSdxyL6fRD7uchn9dI     False
# 9679  034dSXepspHaYFW7rZZx1d     False
# 9680  7oCZpPJcPDZfeIy2t6gqSg     False
# 9681  2kpwzDrLK5KoIk1S5wftX7     False
#
#                                                    name  popularity  \
# 0                                      Midnight $pecial           0
# 1                                                   IDK          16
# 2                                         KILL THEM ALL          29
# 3                                               Destiny           3
# 4                                                 Trife           0
# ...                                                 ...         ...
# 9677  H20 (feat. Pharoahe Monch, Rakaa Iriscience, &...          39
# 9678                                       Daddy's Girl          15
# 9679                                                '94          22
# 9680                                        Born 2 Live          39
# 9681                                      Can't Hold On           0
#
#                                             preview_url  track_number   type  \
# 0     https://p.scdn.co/mp3-preview/fc011f49b21776fb...             1  track
# 1     https://p.scdn.co/mp3-preview/9ab1ae3e08ab1f85...             1  track
# 2                                                  None             3  track
# 3     https://p.scdn.co/mp3-preview/ef98d7a6122e1364...             1  track
# 4                                                  None             1  track
# ...                                                 ...           ...    ...
# 9677  https://p.scdn.co/mp3-preview/c6c1c54a165f9b0a...             3  track
# 9678  https://p.scdn.co/mp3-preview/b1bb7477773c816f...             7  track
# 9679  https://p.scdn.co/mp3-preview/aca9ff38963fff0f...            14  track
# 9680  https://p.scdn.co/mp3-preview/da9dfa06250ce3d8...             4  track
# 9681                                               None             4  track
#
#                                        uri
# 0     spotify:track:2MKznt3SBUurI2dhGBhgKG
# 1     spotify:track:0GpHpTBnQ1VZdlfyBGeoKr
# 2     spotify:track:7in64eGZcfSb6Ag9modv0f
# 3     spotify:track:7pR6pkqITDQSGhSJOzRjWh
# 4     spotify:track:1xWbHRmEAvMXT9nnUtRJM8
# ...                                    ...
# 9677  spotify:track:54v6Kv41W8AKToCb14PmJD
# 9678  spotify:track:4YuGxSdxyL6fRD7uchn9dI
# 9679  spotify:track:034dSXepspHaYFW7rZZx1d
# 9680  spotify:track:7oCZpPJcPDZfeIy2t6gqSg
# 9681  spotify:track:2kpwzDrLK5KoIk1S5wftX7
#
# [9682 rows x 17 columns]

# %%
electro_popularity.to_csv('hiphop_pull.csv')

# %%
electro_popularity = pd.read_csv('hiphop_pull.csv')

# %% [markdown]
# Plot distribution of popularity score.

# %%
sns.histplot(data = electro_popularity
            ,x = 'popularity'
            ).set(title='Total Popularity Distribution')
# Out:
# [Text(0.5, 1.0, 'Total Popularity Distribution')]

# %%
sns.histplot(data = electro_popularity.loc[electro_popularity['popularity'] > 0]
            ,x = 'popularity'
            ).set(title='Non-0 Popularity Distribution')
# Out:
# [Text(0.5, 1.0, 'Non-0 Popularity Distribution')]

# %%
## remove any songs with no popularity - assuming these are too small to be considered
electro_short = electro_popularity.loc[electro_popularity['popularity'] > 0]

# %%
# parse artist names from JSON response
def parse_artist(df):
  empty = []
  for i in df['artists']:
    line_artists = []
    try:
      artist_lists = json.loads(i.replace("\'", "\""))
    except:
      #print(i)
      artists_lists = []
    for j in artist_lists:
      line_artists.append(j['name'])
    empty.append(line_artists)
  return empty


electro_short['artist_names'] = parse_artist(electro_short)
electro_short['first_artist'] = electro_short.apply(lambda row: row.artist_names[0], axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
out = pd.DataFrame(electro_short.first_artist.value_counts())
out
# Out:
#                    first_artist
# BONES                       136
# Pouya                        88
# Xavier Wulf                  70
# Ghostemane                   68
# Kendrick Lamar               68
# ...                         ...
# Jefe Wit The Shot             1
# Fijimacintosh                 1
# Coi Leray                     1
# The Execs                     1
# Skipper                       1
#
# [1977 rows x 1 columns]

# %%
sns.histplot(data = out.loc[out['first_artist'] < 40]
            ,x = 'first_artist'
            ).set(title='Arist Song Count')
# Out:
# [Text(0.5, 1.0, 'Arist Song Count')]

# %%
use_cols = ['href', 'popularity', 'name', 'first_artist']
electro_short_join = electro_short[use_cols]

# %%
electro_short_join
# Out:
#                                                    href  popularity  \
# 1     https://api.spotify.com/v1/tracks/0GpHpTBnQ1VZ...          16
# 2     https://api.spotify.com/v1/tracks/7in64eGZcfSb...          29
# 3     https://api.spotify.com/v1/tracks/7pR6pkqITDQS...           3
# 5     https://api.spotify.com/v1/tracks/5Qt9JOhdYDkH...           9
# 7     https://api.spotify.com/v1/tracks/5Vh9ObRtwoIk...           2
# ...                                                 ...         ...
# 9675  https://api.spotify.com/v1/tracks/5zEoohLO20of...           5
# 9677  https://api.spotify.com/v1/tracks/54v6Kv41W8AK...          39
# 9678  https://api.spotify.com/v1/tracks/4YuGxSdxyL6f...          15
# 9679  https://api.spotify.com/v1/tracks/034dSXepspHa...          22
# 9680  https://api.spotify.com/v1/tracks/7oCZpPJcPDZf...          39
#
#                                                    name    first_artist
# 1                                                   IDK       NERGRISEN
# 2                                         KILL THEM ALL    Undead Ronin
# 3                                               Destiny           Marco
# 5                                               My Time           JANTU
# 7                                                   OMG          Lil MC
# ...                                                 ...             ...
# 9675                                         Get $ Paid  Tha Dogg Pound
# 9677  H20 (feat. Pharoahe Monch, Rakaa Iriscience, &...    Apollo Brown
# 9678                                       Daddy's Girl    Apollo Brown
# 9679                                                '94    Apollo Brown
# 9680                                        Born 2 Live            O.C.
#
# [7393 rows x 4 columns]

# %%
genres_joined = pd.merge(genres.drop('genre', axis=1).drop_duplicates(), 
                         electro_short_join.drop_duplicates(),
                         left_on='track_href', right_on='href', how='left')
genres_joined_electro = genres_joined.loc[~pd.isna(genres_joined.first_artist)]

# %%
genres_joined_electro.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature', 'song_name', 'Unnamed: 0', 'title', 'href',
#        'popularity', 'name', 'first_artist'],
#       dtype='object')

# %%
agg_cols = {'danceability':'mean',
            'energy':'mean',
            'key': 'mean',
            'loudness':'mean',
            #'mode':'mean',
            'speechiness':'mean',
            'acousticness':'mean',
            'instrumentalness':'mean',
            'liveness': 'mean',
            'valence':'mean',
            'tempo':'mean',
            'popularity': 'mean'}

electro_agg_metrics = genres_joined_electro.groupby('first_artist').agg(agg_cols)

# %%
electro_agg_metrics
# Out:
#                 danceability    energy        key   loudness  speechiness  \
# first_artist
# $NOT                0.724089  0.519844   4.644444  -9.405511     0.274020
# $US VALENTINO       0.733000  0.558000   1.000000  -9.513000     0.084700
# $atori Zoom         0.843250  0.624875   2.500000  -7.230125     0.167013
# $hun                0.808000  0.488000   9.000000 -10.927000     0.446000
# $onoma              0.739000  0.806000   8.000000  -5.756000     0.101000
# ...                      ...       ...        ...        ...          ...
# whiterosemoxie      0.829000  0.539000   2.000000  -7.625000     0.185000
# windchILL           0.738000  0.860000  11.000000  -4.077000     0.263000
# woodsordeath        0.778000  0.599000   1.000000  -7.609000     0.199500
# zaya                0.675000  0.742000   1.000000  -6.558000     0.063100
# ✦ pink cig ✦        0.392000  0.421000   6.000000  -9.112500     0.067250
#
#                 acousticness  instrumentalness  liveness   valence  \
# first_artist
# $NOT                0.353913          0.041001  0.171944  0.419271
# $US VALENTINO       0.040000          0.000105  0.333000  0.290000
# $atori Zoom         0.127350          0.006667  0.207763  0.415875
# $hun                0.727000          0.000000  0.110000  0.482000
# $onoma              0.056600          0.000066  0.088400  0.152000
# ...                      ...               ...       ...       ...
# whiterosemoxie      0.029200          0.000000  0.148000  0.335000
# windchILL           0.204000          0.000000  0.212000  0.837000
# woodsordeath        0.040090          0.000000  0.296500  0.217050
# zaya                0.019600          0.879000  0.148000  0.305000
# ✦ pink cig ✦        0.252500          0.000020  0.108000  0.065900
#
#                      tempo  popularity
# first_artist
# $NOT            158.485844   50.933333
# $US VALENTINO   157.945000   37.000000
# $atori Zoom     176.350250   44.750000
# $hun            184.142000   29.000000
# $onoma          129.925000   29.000000
# ...                    ...         ...
# whiterosemoxie  119.950000   51.000000
# windchILL       185.984000   34.000000
# woodsordeath    127.536500   33.000000
# zaya            110.002000   51.000000
# ✦ pink cig ✦    156.824000   29.000000
#
# [1977 rows x 11 columns]

# %%
corr = electro_agg_metrics.corr()

fig, ax = plt.subplots(figsize = (12,8))

sns.heatmap(corr, mask = np.triu(np.ones_like(corr, dtype = bool)), cmap = 'Blues', annot = True, 
           linewidths = .2)

plt.title('Heatmap of Modeling Features', fontsize = 15)
plt.show()

# %%
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(electro_agg_metrics.drop('popularity', axis = 1), 
                                                                            electro_agg_metrics.popularity,
                                                    random_state = 1111,
                                                    test_size = 0.3)

# %%
## Create dictionary to track model results
results = {}

def add_results(y_pred, model_name):
    ## Add results of test data to tracker, with user input to ensure data is overwritten on purpose
    if model_name in results.keys():
        userIn = input("Model already in dictionary. Add? ").lower()
        if userIn == 'yes':
            results[model_name] = round(sklearn.metrics.mean_squared_error(y_test, y_pred), 2)**.5
        else:
            pass
    else:
        results[model_name] = round(sklearn.metrics.mean_squared_error(y_test, y_pred), 2)**.5
    print(results)

# %%
XGB_MVP = xgb.XGBRegressor(objective='reg:squarederror',
                                seed=100).fit(X_train, y_train)
add_results(XGB_MVP.predict(X_test), "XGB_Base")
# Out:
# {'XGB_Base': 17.40718242565407}

# %%
## Run GridSearchCV on max_depth, min_child_weight, n_estimators, and subsample

param_test = {
 'max_depth':range(2,5,1),
 'min_child_weight':range(3,10,2),
 'subsample':[i/100.0 for i in range(70,90,5)],
 'n_estimator':range(150,300,50)
}

gsearch1 = sklearn.model_selection.GridSearchCV(estimator=xgb.XGBRegressor(objective='reg:squarederror', eta=0.025,
                                                                           seed=100),param_grid=param_test, 
                                                                           cv=4)
gsearch1.fit(X_train, y_train)
gsearch1.best_estimator_
# Out:
# XGBRegressor(eta=0.025, max_depth=2, min_child_weight=3, n_estimator=150,
#              objective='reg:squarederror', seed=100, subsample=0.75)

# %%
## Select final number of estimators
params = {'eta':0.025, 'seed':100, 
         'max_depth':3, 'min_child_weight':3, 'subsample':0.75, 'objective':'reg:squarederror'}

## Run CV to determine the number of round
CVRun = xgb.cv(
            params=params,
            dtrain=xgb.DMatrix(X_train, label=y_train),
            num_boost_round=500,
            nfold=4,
            metrics='rmse',
            seed=100)

CVRun.drop(['train-rmse-std', 'test-rmse-std'], axis=1, inplace=True)
CVRun.plot(figsize = (10,5), grid = True)

# %%
## Selected 300 as the number of rounds to avoid over fitting

XGB_hyperparam = xgb.train(params, xgb.DMatrix(X_train, label=y_train), 120)
add_results(XGB_hyperparam.predict(xgb.DMatrix(X_test)), "XGB_Hyperparam")
# Out:
# {'XGB_Base': 17.40718242565407, 'XGB_Hyperparam': 17.134759992483115}

# %%
plt.figure(figsize=(10,10))
plt.scatter(y_test, XGB_hyperparam.predict(xgb.DMatrix(X_test)), c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(XGB_hyperparam.predict(xgb.DMatrix(X_test))), max(y_test))
p2 = min(min(XGB_hyperparam.predict(xgb.DMatrix(X_test))), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()

# %% [markdown]
# ## pull from MusixMatch

# %%
genres_joined_electro.head()
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.831   0.814    2    -7.364     1        0.420        0.0598
# 5          0.721   0.568    0   -11.295     1        0.414        0.0452
# 8          0.774   0.751    1    -2.445     1        0.198        0.0614
# 9          0.893   0.907   11   -10.406     1        0.367        0.1520
# 12         0.825   0.761    8    -5.389     1        0.104        0.0111
#
#     instrumentalness  liveness  valence  ...  \
# 0            0.01340    0.0556    0.389  ...
# 5            0.21200    0.1280    0.109  ...
# 8            0.00000    0.0728    0.189  ...
# 9            0.03110    0.5580    0.302  ...
# 12           0.00359    0.3340    0.161  ...
#
#                                          analysis_url duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/2Vc6...      124539
# 5   https://api.spotify.com/v1/audio-analysis/6fsy...      112511
# 8   https://api.spotify.com/v1/audio-analysis/37gq...      140326
# 9   https://api.spotify.com/v1/audio-analysis/2ggq...      121979
# 12  https://api.spotify.com/v1/audio-analysis/5o7Z...      163371
#
#    time_signature                     song_name Unnamed: 0 title  \
# 0               4           Mercury: Retrograde        NaN   NaN
# 5               4                       Gatteka        NaN   NaN
# 8               4  I Put My Dick in Your Mental        NaN   NaN
# 9               4                     Andromeda        NaN   NaN
# 12              4                   1000 Rounds        NaN   NaN
#
#                                                  href  popularity  \
# 0   https://api.spotify.com/v1/tracks/2Vc6NJ9PW9gD...        74.0
# 5   https://api.spotify.com/v1/tracks/6fsypiJHyWme...        58.0
# 8   https://api.spotify.com/v1/tracks/37gqBnUAZe8B...        51.0
# 9   https://api.spotify.com/v1/tracks/2ggqfj97qyiO...        61.0
# 12  https://api.spotify.com/v1/tracks/5o7ZDvfOry1M...        68.0
#
#                             name  first_artist
# 0            Mercury: Retrograde    Ghostemane
# 5                        Gatteka    Ghostemane
# 8   I Put My Dick in Your Mental         gizmo
# 9                      Andromeda    Ghostemane
# 12                   1000 Rounds         Pouya
#
# [5 rows x 25 columns]

# %%
musixmatch = Musixmatch(musix_cid)

def parse_lyrics(df):
  empty = []
  for row, artist in df.first_artist.iteritems():
    song_title = df['name'].loc[row]
    lyrics_return = ''
    #print(song_title)
    #print(artist)
    try:
      track_return = musixmatch.matcher_track_get(song_title, artist)
      if track_return['message']['body']['track']['has_lyrics'] == 1:
        lyrics_return = musixmatch.track_lyrics_get(track_return['message']['body']['track']['track_id'])['message']['body']['lyrics']['lyrics_body']
    except:
      lyrics_return = ''
    empty.append(lyrics_return)
  return empty

full_lyrics = parse_lyrics(genres_joined_electro)

# %%
genres_joined_electro['lyrics'] = full_lyrics
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
## clean lyrics
genres_joined_electro['lyrics_clean'] = genres_joined_electro['lyrics'].str.replace('******* This Lyrics is NOT for Commercial use *******\n(1409622602394)', '',regex=False).str.replace('\n', ' ', regex=False)
genres_joined_electro['char_len'] = genres_joined_electro['lyrics_clean'].str.len()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
(genres_joined_electro['char_len'] == 0).astype(int).sum()
# Out:
# 1870

# %%
(genres_joined_electro['char_len'] > 0).astype(int).sum()
# Out:
# 5773

# %%
genres_joined_electro.to_csv('mapped_data_w_lyrics_hiphop.csv')

# %%
sia = SentimentIntensityAnalyzer()

# %%
def get_sentiment(df):
  empty = []
  for lyrics in df.lyrics_clean:
    output = sia.polarity_scores(lyrics)
    empty.append(output)
  return empty

sentiment_scores = pd.DataFrame(get_sentiment(genres_joined_electro))
final_sentiment = pd.concat([genres_joined_electro.reset_index(), sentiment_scores.reset_index()], axis=1)

# %%
final_sentiment
# Out:
#       index  danceability  energy  key  loudness  mode  speechiness  \
# 0         0         0.831   0.814    2    -7.364     1       0.4200
# 1         5         0.721   0.568    0   -11.295     1       0.4140
# 2         8         0.774   0.751    1    -2.445     1       0.1980
# 3         9         0.893   0.907   11   -10.406     1       0.3670
# 4        12         0.825   0.761    8    -5.389     1       0.1040
# ...     ...           ...     ...  ...       ...   ...          ...
# 7638  18673         0.785   0.648    7    -6.907     1       0.2790
# 7639  19172         0.696   0.787    4    -6.805     1       0.0496
# 7640  19940         0.696   0.787    4    -6.805     1       0.0496
# 7641  20474         0.696   0.787    4    -6.805     1       0.0496
# 7642  21269         0.696   0.787    4    -6.805     1       0.0496
#
#       acousticness  instrumentalness  liveness  ...  \
# 0         0.059800           0.01340    0.0556  ...
# 1         0.045200           0.21200    0.1280  ...
# 2         0.061400           0.00000    0.0728  ...
# 3         0.152000           0.03110    0.5580  ...
# 4         0.011100           0.00359    0.3340  ...
# ...            ...               ...       ...  ...
# 7638      0.015700           0.00198    0.1000  ...
# 7639      0.000405           0.33900    0.0477  ...
# 7640      0.000405           0.33900    0.0477  ...
# 7641      0.000405           0.33900    0.0477  ...
# 7642      0.000405           0.33900    0.0477  ...
#
#                               name  first_artist  \
# 0              Mercury: Retrograde    Ghostemane
# 1                          Gatteka    Ghostemane
# 2     I Put My Dick in Your Mental         gizmo
# 3                        Andromeda    Ghostemane
# 4                      1000 Rounds         Pouya
# ...                            ...           ...
# 7638                   Born 2 Live          O.C.
# 7639      Tribesmen - Original Mix       Solardo
# 7640      Tribesmen - Original Mix       Solardo
# 7641      Tribesmen - Original Mix       Solardo
# 7642      Tribesmen - Original Mix       Solardo
#
#                                                  lyrics  \
# 0     Ask me if I give a fuck about a clique, ay\nAs...
# 1     See I just can't relate\nYou try to pretend we...
# 2     Lunarvision (lunarvision, lunarvision, lunarvi...
# 3     (Ayy yeah, fuck everything bitch)\n(Hell yeah)...
# 4     Bullets fly, legs buckle, bodies pile to the s...
# ...                                                 ...
# 7638  Like the dead end kids we used to play in the ...
# 7639
# 7640
# 7641
# 7642
#
#                                            lyrics_clean char_len index    neg  \
# 0     Ask me if I give a fuck about a clique, ay Ask...      526     0  0.280
# 1     See I just can't relate You try to pretend we'...      433     1  0.145
# 2     Lunarvision (lunarvision, lunarvision, lunarvi...      462     2  0.292
# 3     (Ayy yeah, fuck everything bitch) (Hell yeah) ...      534     3  0.194
# 4     Bullets fly, legs buckle, bodies pile to the s...      917     4  0.122
# ...                                                 ...      ...   ...    ...
# 7638  Like the dead end kids we used to play in the ...     1253  7638  0.191
# 7639                                                           0  7639  0.000
# 7640                                                           0  7640  0.000
# 7641                                                           0  7641  0.000
# 7642                                                           0  7642  0.000
#
#         neu    pos compound
# 0     0.639  0.081  -0.9819
# 1     0.712  0.143   0.4404
# 2     0.650  0.058  -0.9779
# 3     0.534  0.272   0.7704
# 4     0.861  0.017  -0.9575
# ...     ...    ...      ...
# 7638  0.691  0.118  -0.9795
# 7639  0.000  0.000   0.0000
# 7640  0.000  0.000   0.0000
# 7641  0.000  0.000   0.0000
# 7642  0.000  0.000   0.0000
#
# [7643 rows x 34 columns]

# %%
agg_cols = {'danceability':'mean',
            'energy':'mean',
            'key': 'mean',
            'loudness':'mean',
            #'mode':'mean',
            'speechiness':'mean',
            'acousticness':'mean',
            'instrumentalness':'mean',
            'liveness': 'mean',
            'valence':'mean',
            'tempo':'mean',
            'neg':'mean',
            'neu':'mean',
            'pos':'mean',
            'compound':'mean',
            'popularity': 'mean'}

electro_agg_metrics = final_sentiment.groupby('first_artist').agg(agg_cols)

electro_agg_metrics
# Out:
#                 danceability    energy        key   loudness  speechiness  \
# first_artist
# $NOT                0.724089  0.519844   4.644444  -9.405511     0.274020
# $US VALENTINO       0.733000  0.558000   1.000000  -9.513000     0.084700
# $atori Zoom         0.843250  0.624875   2.500000  -7.230125     0.167013
# $hun                0.808000  0.488000   9.000000 -10.927000     0.446000
# $onoma              0.739000  0.806000   8.000000  -5.756000     0.101000
# ...                      ...       ...        ...        ...          ...
# whiterosemoxie      0.829000  0.539000   2.000000  -7.625000     0.185000
# windchILL           0.738000  0.860000  11.000000  -4.077000     0.263000
# woodsordeath        0.778000  0.599000   1.000000  -7.609000     0.199500
# zaya                0.675000  0.742000   1.000000  -6.558000     0.063100
# ✦ pink cig ✦        0.392000  0.421000   6.000000  -9.112500     0.067250
#
#                 acousticness  instrumentalness  liveness   valence  \
# first_artist
# $NOT                0.353913          0.041001  0.171944  0.419271
# $US VALENTINO       0.040000          0.000105  0.333000  0.290000
# $atori Zoom         0.127350          0.006667  0.207763  0.415875
# $hun                0.727000          0.000000  0.110000  0.482000
# $onoma              0.056600          0.000066  0.088400  0.152000
# ...                      ...               ...       ...       ...
# whiterosemoxie      0.029200          0.000000  0.148000  0.335000
# windchILL           0.204000          0.000000  0.212000  0.837000
# woodsordeath        0.040090          0.000000  0.296500  0.217050
# zaya                0.019600          0.879000  0.148000  0.305000
# ✦ pink cig ✦        0.252500          0.000020  0.108000  0.065900
#
#                      tempo       neg       neu       pos  compound  popularity
# first_artist
# $NOT            158.485844  0.159244  0.616444  0.113156 -0.289980   50.933333
# $US VALENTINO   157.945000  0.091000  0.820000  0.089000 -0.300800   37.000000
# $atori Zoom     176.350250  0.186625  0.711375  0.102000 -0.687975   44.750000
# $hun            184.142000  0.000000  0.000000  0.000000  0.000000   29.000000
# $onoma          129.925000  0.000000  0.000000  0.000000  0.000000   29.000000
# ...                    ...       ...       ...       ...       ...         ...
# whiterosemoxie  119.950000  0.062000  0.874000  0.064000 -0.381800   51.000000
# windchILL       185.984000  0.169000  0.684000  0.147000 -0.700300   34.000000
# woodsordeath    127.536500  0.000000  0.000000  0.000000  0.000000   33.000000
# zaya            110.002000  0.304000  0.657000  0.039000 -0.993100   51.000000
# ✦ pink cig ✦    156.824000  0.188500  0.698500  0.113000 -0.505200   29.000000
#
# [1977 rows x 15 columns]

# %%
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(electro_agg_metrics.drop('popularity', axis = 1), 
                                                                            electro_agg_metrics.popularity,
                                                    random_state = 1111,
                                                    test_size = 0.3)

# %%
XGB_MVP = xgb.XGBRegressor(objective='reg:squarederror',
                                seed=100).fit(X_train, y_train)
add_results(XGB_MVP.predict(X_test), "XGB_Base_lyrics")
# Out:
# {'XGB_Base': 17.40718242565407, 'XGB_Hyperparam': 17.134759992483115, 'XGB_Base_lyrics': 15.426600403199663}

# %%
## Run GridSearchCV on max_depth, min_child_weight, n_estimators, and subsample

param_test = {
 'max_depth':range(2,5,1),
 'min_child_weight':range(3,10,2),
 'subsample':[i/100.0 for i in range(70,90,5)],
 'n_estimator':range(150,300,50)
}

gsearch1 = sklearn.model_selection.GridSearchCV(estimator=xgb.XGBRegressor(objective='reg:squarederror', eta=0.025,
                                                                           seed=100),param_grid=param_test, 
                                                                           cv=4)
gsearch1.fit(X_train, y_train)
gsearch1.best_estimator_
# Out:
# XGBRegressor(eta=0.025, max_depth=2, min_child_weight=5, n_estimator=150,
#              objective='reg:squarederror', seed=100, subsample=0.8)

# %%
## Select final number of estimators
params = {'eta':0.025, 'seed':100, 
         'max_depth':2, 'min_child_weight':5, 'subsample':0.8, 'objective':'reg:squarederror'}

## Run CV to determine the number of round
CVRun = xgb.cv(
            params=params,
            dtrain=xgb.DMatrix(X_train, label=y_train),
            num_boost_round=500,
            nfold=4,
            metrics='rmse',
            seed=100)

CVRun.drop(['train-rmse-std', 'test-rmse-std'], axis=1, inplace=True)
CVRun.plot(figsize = (10,5), grid = True)

# %%
## Selected 300 as the number of rounds to avoid over fitting

XGB_hyperparam = xgb.train(params, xgb.DMatrix(X_train, label=y_train), 140)
add_results(XGB_hyperparam.predict(xgb.DMatrix(X_test)), "XGB_Hyperparam_lyrics")
# Out:
# {'XGB_Base': 17.40718242565407, 'XGB_Hyperparam': 17.134759992483115, 'XGB_Base_lyrics': 15.426600403199663, 'XGB_Hyperparam_lyrics': 15.27481587450402}

# %%
plt.figure(figsize=(10,10))
plt.scatter(y_test, XGB_hyperparam.predict(xgb.DMatrix(X_test)), c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(XGB_hyperparam.predict(xgb.DMatrix(X_test))), max(y_test))
p2 = min(min(XGB_hyperparam.predict(xgb.DMatrix(X_test))), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()
